# %% [markdown]
# <a href="https://colab.research.google.com/github/YulyaZh/-/blob/main/%D0%B4%D0%BE%D0%BF%D0%BE%D0%BB%D0%BD%D0%B8%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D0%BE%D0%B5_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_%D0%BF%D0%BE_%D0%BC%D0%B0%D1%88%D0%B8%D0%BD%D0%BD%D0%BE%D0%BC%D1%83_%D0%BE%D0%B1%D1%83%D1%87%D0%B5%D0%BD%D0%B8%D1%8E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("Домашняя бухгалтерия.csv", sep=",")

# %%
df.head()
# Out:
#    траты в позапрошлом месяце  траты в прошлом месяце  траты в тек. месяце  \
# 0                     12500.0                 12500.0              12500.0
# 1                       700.0                   800.0                900.0
# 2                       900.0                  1000.0               1100.0
# 3                      7000.0                  8000.0               8200.0
# 4                      9000.0                  9500.0               9800.0
#
#    траты в след. месяце
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   траты в позапрошлом месяце  9 non-null      float64
#  1   траты в прошлом месяце      9 non-null      float64
#  2   траты в тек. месяце         9 non-null      float64
#  3   траты в след. месяце        0 non-null      float64
# dtypes: float64(4)
# memory usage: 416.0 bytes

# %%
df.describe()
# Out:
#        траты в позапрошлом месяце  траты в прошлом месяце  \
# count                    9.000000                9.000000
# mean                  3605.555556             3861.111111
# std                   4636.839201             4746.694756
# min                    450.000000              550.000000
# 25%                    600.000000              700.000000
# 50%                    800.000000             1000.000000
# 75%                   7000.000000             8000.000000
# max                  12500.000000            12500.000000
#
#        траты в тек. месяце  траты в след. месяце
# count             9.000000                   0.0
# mean           3994.444444                   NaN
# std            4756.077983                   NaN
# min             750.000000                   NaN
# 25%             900.000000                   NaN
# 50%            1000.000000                   NaN
# 75%            8200.000000                   NaN
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
df.columns
# Out:
# Index(['траты в позапрошлом месяце', 'траты в прошлом месяце',
#        'траты в тек. месяце', 'траты в след. месяце'],
#       dtype='object')

# %%
x = df[['траты в позапрошлом месяце', 'траты в прошлом месяце', 'траты в тек. месяце']]
y = df['траты в след. месяце']

# %%
y
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# Name: траты в след. месяце, dtype: float64

# %%
x
# Out:
#    траты в позапрошлом месяце  траты в прошлом месяце  траты в тек. месяце
# 0                     12500.0                 12500.0              12500.0
# 1                       700.0                   800.0                900.0
# 2                       900.0                  1000.0               1100.0
# 3                      7000.0                  8000.0               8200.0
# 4                      9000.0                  9500.0               9800.0
# 5                       450.0                   550.0                750.0
# 6                       600.0                   700.0                800.0
# 7                       500.0                   700.0                900.0
# 8                       800.0                  1000.0               1000.0

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train
# Out:
#    траты в позапрошлом месяце  траты в прошлом месяце  траты в тек. месяце
# 3                      7000.0                  8000.0               8200.0
# 2                       900.0                  1000.0               1100.0
# 1                       700.0                   800.0                900.0
# 4                      9000.0                  9500.0               9800.0
# 5                       450.0                   550.0                750.0
# 7                       500.0                   700.0                900.0
# 0                     12500.0                 12500.0              12500.0

# %%
X_test
# Out:
#    траты в позапрошлом месяце  траты в прошлом месяце  траты в тек. месяце
# 6                       600.0                   700.0                800.0
# 8                       800.0                  1000.0               1000.0

# %%
y_train
# Out:
# 3   NaN
# 2   NaN
# 1   NaN
# 4   NaN
# 5   NaN
# 7   NaN
# 0   NaN
# Name: траты в след. месяце, dtype: float64

# %%
y_test
# Out:
# 6   NaN
# 8   NaN
# Name: траты в след. месяце, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-4311d9257fbf> in <module>
# ----> 1 lr.fit(X_train, y_train)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     661
#     662         X, y = self._validate_data(
# --> 663             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664         )
#     665
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ...
